# %%
import pandas as pd

# %%
data=pd.read_csv('2020.txt',encoding='UTF-8')
data.head()
# Out:
#    기준년도  경찰서명  신고건수  신고성별(남자)  신고성별(여자)  신고성별(불상)  신고 성별(기타)  접수긴급유형(긴급)  \
# 0  2020   ETC  3031       890      1956       175          9          39
# 1  2020    무주    12         2         9         1          0           1
# 2  2020  대전중부   340       113       213        14          0           6
# 3  2020  서울노원   831       271       498        62          0          29
# 4  2020  마산중부   166        53       110         3          0           9
#
#    접수긴급유형(중요)  접수긴급유형(일반)  ...  발생시간대(14)  발생시간대(15)  발생시간대(16)  발생시간대(17)  \
# 0        2047         445  ...        119        100        111        116
# 1          10           1  ...          0          0          0          0
# 2         211          91  ...         22          9          8         16
# 3         687          74  ...         37         41         29         33
# 4         114          33  ...          9          7          6         13
#
#    발생시간대(18)  발생시간대(19)  발생시간대(20)  발생시간대(21)  발생시간대(22)  발생시간대(23)
# ...

# %%
df=pd.DataFrame(data)
df
# Out:
#      기준년도  경찰서명  신고건수  신고성별(남자)  신고성별(여자)  신고성별(불상)  신고 성별(기타)  접수긴급유형(긴급)  \
# 0    2020   ETC  3031       890      1956       175          9          39
# 1    2020    무주    12         2         9         1          0           1
# 2    2020  대전중부   340       113       213        14          0           6
# 3    2020  서울노원   831       271       498        62          0          29
# 4    2020  마산중부   166        53       110         3          0           9
# ..    ...   ...   ...       ...       ...       ...        ...         ...
# 272  2020  청주청원   307        94       202        11          0           5
# 273  2020    목포   397       122       258        17          0           4
# 274  2020    상주    93        27        65         1          0           0
# 275  2020  포항북부   286        80       190        16          0           3
# 276  2020    함안    39        11        26         2          0           2
#
# ...

# %%
df=df.drop(['기준년도'],axis=1)
df
# Out:
#      경찰서명  신고건수  신고성별(남자)  신고성별(여자)  신고성별(불상)  신고 성별(기타)  접수긴급유형(긴급)  \
# 0     ETC  3031       890      1956       175          9          39
# 1      무주    12         2         9         1          0           1
# 2    대전중부   340       113       213        14          0           6
# 3    서울노원   831       271       498        62          0          29
# 4    마산중부   166        53       110         3          0           9
# ..    ...   ...       ...       ...       ...        ...         ...
# 272  청주청원   307        94       202        11          0           5
# 273    목포   397       122       258        17          0           4
# 274    상주    93        27        65         1          0           0
# 275  포항북부   286        80       190        16          0           3
# 276    함안    39        11        26         2          0           2
#
#      접수긴급유형(중요)  접수긴급유형(일반)  접수긴급유형(민원)  ...  발생시간대(14)  발생시간대(15)  발생시간대(16)  \
# ...

# %%
df=df.set_index('경찰서명')
df
# Out:
#       신고건수  신고성별(남자)  신고성별(여자)  신고성별(불상)  신고 성별(기타)  접수긴급유형(긴급)  접수긴급유형(중요)  \
# 경찰서명
# ETC   3031       890      1956       175          9          39        2047
# 무주      12         2         9         1          0           1          10
# 대전중부   340       113       213        14          0           6         211
# 서울노원   831       271       498        62          0          29         687
# 마산중부   166        53       110         3          0           9         114
# ...    ...       ...       ...       ...        ...         ...         ...
# 청주청원   307        94       202        11          0           5         231
# 목포     397       122       258        17          0           4         295
# 상주      93        27        65         1          0           0          53
# 포항북부   286        80       190        16          0           3         150
# 함안      39        11        26         2          0           2          20
#
# ...

# %%
df.to_csv('2020.csv',encoding='euc-kr')

# %%
# 2020 서울

# %%
seoul_20=df.loc[['서울강남',
'서울강동',
'서울강북',
'서울강서',
'서울관악',
'서울광진',
'서울구로',
'서울금천',
'서울남대문',
'서울노원',
'서울도봉',
'서울동대문',
'서울동작',
'서울마포',
'서울방배',
'서울서대문',
'서울서부',
'서울서초',
'서울성동',
'서울성북',
'서울송파',
'서울수서',
'서울양천',
'서울영등포',
'서울용산',
'서울은평',
'서울종로',
'서울종암',
'서울중랑',
'서울중부',
'서울청',
'서울혜화'
],:]
seoul_20
# Out:
#        신고건수  신고성별(남자)  신고성별(여자)  신고성별(불상)  신고 성별(기타)  접수긴급유형(긴급)  접수긴급유형(중요)  \
# 경찰서명
# 서울강남    238        74       147        17          0           8         178
# 서울강동    575       195       355        25          0          26         430
# 서울강북    437       135       259        43          0          16         364
# 서울강서    734       236       452        46          0          14         574
# 서울관악    549       205       316        28          0          16         433
# 서울광진    345       104       219        22          0          13         254
# 서울구로    495       174       299        22          0          16         397
# 서울금천    320       110       192        18          0          13         259
# 서울남대문    39        10        22         7          0           1          30
# 서울노원    831       271       498        62          0          29         687
# 서울도봉    500       152       313        35          0          16         413
# ...

# %%
seoul_20.to_csv('20_seoul.csv',encoding='euc-kr')

# %%
# 2020 부산

# %%
busan_20=df.loc[['부산강서',
'부산금정',
'부산기장',
'부산남부',
'부산동래',
'부산동부',
'부산북부',
'부산사상',
'부산사하',
'부산서부',
'부산연제',
'부산영도',
'부산중부',
'부산진',
'부산청',
'부산해운대'
],:]
busan_20
# Out:
#        신고건수  신고성별(남자)  신고성별(여자)  신고성별(불상)  신고 성별(기타)  접수긴급유형(긴급)  접수긴급유형(중요)  \
# 경찰서명
# 부산강서    141        42        88        11          0           9          88
# 부산금정    136        33       100         3          0           5         101
# 부산기장    245        58       162        25          0          20         151
# 부산남부    408       115       276        17          0          14         297
# 부산동래    224        70       149         5          0           6         153
# 부산동부     65        20        42         3          0           2          43
# 부산북부    228        62       157         9          0          21         158
# 부산사상    252        73       157        22          0          10         182
# 부산사하    331        83       220        28          0          14         216
# 부산서부     85        24        60         1          0           4          63
# 부산연제    246        73       163        10          0          13         169
# ...

# %%
busan_20.to_csv('20_busan.csv',encoding='euc-kr')

# %%
# 2020 대구

# %%
daegu_20=df.loc[['대구강북',
'대구남부',
'대구달서',
'대구달성',
'대구동부',
'대구북부',
'대구서부',
'대구성서',
'대구수성',
'대구중부',
'대구청'
],:]
daegu_20
# Out:
#       신고건수  신고성별(남자)  신고성별(여자)  신고성별(불상)  신고 성별(기타)  접수긴급유형(긴급)  접수긴급유형(중요)  \
# 경찰서명
# 대구강북   365       122       220        23          0           7         299
# 대구남부   215        68       128        19          0           2         159
# 대구달서   414       147       255        12          0          10         336
# 대구달성   371       126       216        29          0           6         311
# 대구동부   425       125       280        20          0           4         298
# 대구북부   329       107       214         8          0           4         271
# 대구서부   303        91       200        12          0           6         246
# 대구성서   326        89       216        21          0           3         257
# 대구수성   498       158       309        31          0          10         404
# 대구중부    80        24        51         5          0           2          62
# 대구청      3         0         3         0          0           1           2
#
# ...

# %%
daegu_20.to_csv('20_daegu.csv',encoding='euc-kr')

# %%
# 2020 인천

# %%
incheon_20=df.loc[['인천강화',
'인천계양',
'인천국제공항경찰단',
'인천남동',
'인천논현',
'인천미추홀',
'인천부평',
'인천삼산',
'인천서부',
'인천연수',
'인천중부',
'인천청'
],:]
incheon_20
# Out:
#            신고건수  신고성별(남자)  신고성별(여자)  신고성별(불상)  신고 성별(기타)  접수긴급유형(긴급)  \
# 경찰서명
# 인천강화         66        36        27         3          0           2
# 인천계양        421       174       225        22          0          11
# 인천국제공항경찰단     3         0         1         2          0           0
# 인천남동        567       209       322        36          0          13
# 인천논현        453       179       245        29          0          12
# 인천미추홀      1051       334       621        96          0          23
# 인천부평        423       153       248        22          0          12
# 인천삼산        561       196       328        37          0          12
# 인천서부       1085       316       712        57          0          28
# 인천연수        515       179       303        33          0          21
# 인천중부        328       112       197        19          0          12
# 인천청           6         0         6         0          0           0
#
# ...

# %%
incheon_20.to_csv('20_incheon.csv',encoding='euc-kr')

# %%
# 2020 광주

# %%
gwangju_20=df.loc[['광주',
'광주광산',
'광주남부',
'광주동부',
'광주북부',
'광주서부',
'광주청'
],:]
gwangju_20
# Out:
#       신고건수  신고성별(남자)  신고성별(여자)  신고성별(불상)  신고 성별(기타)  접수긴급유형(긴급)  접수긴급유형(중요)  \
# 경찰서명
# 광주     719       255       415        49          0          24         565
# 광주광산   372       107       249        16          0           7         308
# 광주남부   201        58       129        14          0           2         167
# 광주동부   108        43        64         1          0           2          88
# 광주북부   380       126       238        16          0           5         307
# 광주서부   301        78       198        25          0           3         248
# 광주청      2         1         1         0          0           0           1
#
#       접수긴급유형(일반)  접수긴급유형(민원)  접수긴급유형(기타)  ...  발생시간대(14)  발생시간대(15)  \
# 경찰서명                                      ...
# 광주           100          20          10  ...         17         19
# 광주광산          44           7           6  ...          8          9
# 광주남부          24           3           5  ...          8          3
# ...

# %%
gwangju_20.to_csv('20_gwangju.csv',encoding='euc-kr')

# %%
# 2020 대전

# %%
daejeon_20=df.loc[['대전대덕',
'대전동부',
'대전둔산',
'대전서부',
'대전유성',
'대전중부',
'대전청'
],:]
daejeon_20
# Out:
#       신고건수  신고성별(남자)  신고성별(여자)  신고성별(불상)  신고 성별(기타)  접수긴급유형(긴급)  접수긴급유형(중요)  \
# 경찰서명
# 대전대덕   262        95       154        13          0           3         177
# 대전동부   339       110       221         8          0           5         228
# 대전둔산   308       109       183        16          0           2         189
# 대전서부   460       134       311        15          0           2         294
# 대전유성   357       114       223        20          0          14         212
# 대전중부   340       113       213        14          0           6         211
# 대전청      4         1         2         1          0           0           2
#
#       접수긴급유형(일반)  접수긴급유형(민원)  접수긴급유형(기타)  ...  발생시간대(14)  발생시간대(15)  \
# 경찰서명                                      ...
# 대전대덕          64          14           4  ...         12          9
# 대전동부          82          11          13  ...         14         11
# 대전둔산          92           6          19  ...         19         14
# ...

# %%
daejeon_20.to_csv('20_daejeon.csv',encoding='euc-kr')

# %%
# 2020 울산

# %%
ulsan_20=df.loc[['울산남부',
'울산동부',
'울산울주',
'울산중부',
'울산청'
],:]
ulsan_20
# Out:
#       신고건수  신고성별(남자)  신고성별(여자)  신고성별(불상)  신고 성별(기타)  접수긴급유형(긴급)  접수긴급유형(중요)  \
# 경찰서명
# 울산남부   518       167       307        44          0           7         393
# 울산동부   268        68       176        23          1           7         183
# 울산울주   303        84       202        17          0           3         217
# 울산중부   438       118       292        28          0          11         318
# 울산청      3         1         2         0          0           0           2
#
#       접수긴급유형(일반)  접수긴급유형(민원)  접수긴급유형(기타)  ...  발생시간대(14)  발생시간대(15)  \
# 경찰서명                                      ...
# 울산남부          80          17          21  ...         21         16
# 울산동부          58          17           3  ...          9          8
# 울산울주          62          16           5  ...         12         16
# 울산중부          80          18          11  ...         19         24
# 울산청            1           0           0  ...          2          0
#
# ...

# %%
ulsan_20.to_csv('20_ulsan.csv',encoding='euc-kr')

# %%
# 2020 경기

# %%
gyeonggi_20=df.loc[['가평',
'경기남부청',
'경기북부청',
'고양',
'과천',
'광명',
'구리',
'군포',
'김포',
'남양주',
'동두천',
'부천소사',
'부천오정',
'부천원미',
'분당',
'성남수정',
'성남중원',
'수원남부',
'수원서부',
'수원중부',
'시흥',
'안산단원',
'안산상록',
'안성',
'안양동안',
'안양만안',
'양주',
'양평',
'여주',
'연천',
'오산',
'용인동부',
'용인서부',
'의왕',
'의정부',
'이천',
'일산동부',
'일산서부',
'파주',
'평택',
'포천',
'하남',
'화성동탄',
'화성서부',
],:]
gyeonggi_20
# Out:
#        신고건수  신고성별(남자)  신고성별(여자)  신고성별(불상)  신고 성별(기타)  접수긴급유형(긴급)  접수긴급유형(중요)  \
# 경찰서명
# 가평       95        30        64         1          0           1          74
# 경기남부청    19         7        10         2          0           3          12
# 경기북부청     5         0         5         0          0           0           4
# 고양      595       203       351        41          0          16         473
# 과천       57        12        40         5          0           2          48
# 광명      536       175       313        48          0          17         439
# 구리      236        74       154         8          0           1         197
# 군포      289        80       173        36          0           8         226
# 김포      782       254       489        39          0          19         612
# 남양주     403       123       258        22          0           4         338
# 동두천     168        62       100         6          0           0         144
# ...

# %%
gyeonggi_20.to_csv('20_gyeonggi.csv',encoding='euc-kr')

# %%
# 2020 강원

# %%
gangwon_20=df.loc[['강릉',
'강원도고성',
'강원청',
'동해',
'삼척',
'속초',
'양구',
'영월',
'원주',
'인제',
'정선',
'철원',
'춘천',
'태백',
'평창',
'홍천',
'화천',
'횡성'
],:]
gangwon_20
# Out:
#        신고건수  신고성별(남자)  신고성별(여자)  신고성별(불상)  신고 성별(기타)  접수긴급유형(긴급)  접수긴급유형(중요)  \
# 경찰서명
# 강릉      360       121       217        22          0           7         258
# 강원도고성    18        11         7         0          0           0           9
# 강원청       4         1         2         1          0           0           1
# 동해      174        70        98         6          0           3         104
# 삼척      110        31        75         4          0           3          74
# 속초      131        31        91         9          0           1          92
# 양구       16         6         9         1          0           0          12
# 영월       43         8        31         4          0           0          23
# 원주      583       173       387        23          0           4         407
# 인제       30        12        18         0          0           0          23
# 정선       56        15        35         6          0           2          34
# ...

# %%
gangwon_20.to_csv('20_gangwon.csv',encoding='euc-kr')

# %%
# 2020 충북

# %%
chungbuk_20=df.loc[['괴산',
'단양',
'보은',
'영동',
'옥천',
'음성',
'제천',
'진천',
'청주상당',
'청주청원',
'청주흥덕',
'충북청',
'충주'
],:]
chungbuk_20
# Out:
#       신고건수  신고성별(남자)  신고성별(여자)  신고성별(불상)  신고 성별(기타)  접수긴급유형(긴급)  접수긴급유형(중요)  \
# 경찰서명
# 괴산      52         9        43         0          0           1          36
# 단양      19         8        11         0          0           0          15
# 보은      25         5        19         1          0           3          19
# 영동      37        10        24         3          0           0          27
# 옥천      50        12        31         7          0           1          37
# 음성     147        44        96         7          0           3          99
# 제천     182        62       115         5          0           3         144
# 진천      43        12        29         2          0           0          31
# 청주상당   389       138       236        15          0          10         286
# 청주청원   307        94       202        11          0           5         231
# 청주흥덕   383       123       230        30          0           3         273
# ...

# %%
chungbuk_20.to_csv('20_chungbuk.csv',encoding='euc-kr')

# %%
# 2020 충남

# %%
chungnam_20=df.loc[['공주',
'금산',
'논산',
'당진',
'보령',
'부여',
'서산',
'서천',
'아산',
'예산',
'천안동남',
'천안서북',
'청양',
'충남청',
'태안',
'홍성'
],:]
chungnam_20
# Out:
#       신고건수  신고성별(남자)  신고성별(여자)  신고성별(불상)  신고 성별(기타)  접수긴급유형(긴급)  접수긴급유형(중요)  \
# 경찰서명
# 공주      95        34        55         6          0           4          72
# 금산      38        14        23         1          0           1          29
# 논산     203        74       125         4          0           5         162
# 당진     169        57        95        17          0           1         130
# 보령     127        42        77         8          0           6          92
# 부여      62        22        36         4          0           1          49
# 서산     270        91       172         7          0           2         211
# 서천      47         9        37         1          0           2          36
# 아산     383       135       239         9          0           8         290
# 예산      91        35        54         2          0           1          64
# 천안동남   400       113       263        24          0           4         305
# ...

# %%
chungnam_20.to_csv('20_chungnam.csv',encoding='euc-kr')

# %%
# 2020 전북

# %%
jeonbuk_20=df.loc[['고창',
'군산',
'김제',
'남원',
'무주',
'부안',
'순창',
'완주',
'익산',
'임실',
'장수',
'전북청',
'전주덕진',
'전주완산',
'정읍',
'진안'
],:]
jeonbuk_20
# Out:
#       신고건수  신고성별(남자)  신고성별(여자)  신고성별(불상)  신고 성별(기타)  접수긴급유형(긴급)  접수긴급유형(중요)  \
# 경찰서명
# 고창      34         8        24         2          0           0          27
# 군산     188        69       113         6          0           6         141
# 김제      41        11        29         1          0           0          34
# 남원      75        31        42         2          0           3          49
# 무주      12         2         9         1          0           1          10
# 부안      45         7        37         1          0           2          28
# 순창      21         5        16         0          0           0          16
# 완주      59        19        31         9          0           5          39
# 익산     187        76       103         7          0           7         142
# 임실       3         0         3         0          0           0           1
# 장수      25         9        13         3          0           1          12
# ...

# %%
jeonbuk_20.to_csv('20_jeonbuk.csv',encoding='euc-kr')

# %%
# 2020 전남

# %%
jeonnam_20=df.loc[['강진',
'고흥',
'곡성',
'광양',
'구례',
'나주',
'담양',
'목포',
'무안',
'보성',
'순천',
'여수',
'영광',
'영암',
'완도',
'장성',
'장흥',
'전남청',
'진도',
'해남',
'화순'
],:]
jeonnam_20
# Out:
#       신고건수  신고성별(남자)  신고성별(여자)  신고성별(불상)  신고 성별(기타)  접수긴급유형(긴급)  접수긴급유형(중요)  \
# 경찰서명
# 강진      34        14        20         0          0           1          24
# 고흥      64        19        43         2          0           1          51
# 곡성      13         1        12         0          0           0          11
# 광양     178        51       114        13          0           4         135
# 구례      21         8        13         0          0           1          16
# 나주     120        30        86         4          0           1          82
# 담양      22         4        16         2          0           0          18
# 목포     397       122       258        17          0           4         295
# 무안      93        21        70         2          0           1          71
# 보성      29         7        20         2          0           0          24
# 순천     375       121       236        18          0           4         297
# ...

# %%
jeonnam_20.to_csv('20_jeonnam.csv',encoding='euc-kr')

# %%
# 2020 경북

# %%
gyeongbuk_20=df.loc[['경북청',
'경산',
'경주',
'고령',
'구미',
'군위',
'김천',
'문경',
'봉화',
'상주',
'성주',
'안동',
'영덕',
'영양',
'영주',
'영천',
'예천',
'울릉',
'울진',
'의성',
'청도',
'청송',
'칠곡',
'포항남부',
'포항북부'
],:]
gyeongbuk_20
# Out:
#       신고건수  신고성별(남자)  신고성별(여자)  신고성별(불상)  신고 성별(기타)  접수긴급유형(긴급)  접수긴급유형(중요)  \
# 경찰서명
# 경북청     12         6         6         0          0           0           8
# 경산     271        93       154        24          0           3         159
# 경주     252        64       162        26          0           5         127
# 고령      12         5         7         0          0           0           9
# 구미     463       156       279        28          0           6         260
# 군위      14         4         9         1          0           0           9
# 김천     154        37       109         8          0           2          93
# 문경      51        18        32         1          0           0          32
# 봉화      32         7        25         0          0           1          18
# 상주      93        27        65         1          0           0          53
# 성주      28        11        17         0          0           0          17
# ...

# %%
gyeongbuk_20.to_csv('20_gyeongbuk.csv',encoding='euc-kr')

# %%
# 2020 경남

# %%
gyeongnam_20=df.loc[['거제',
'거창',
'경남청',
'경상남도고성',
'김해서부',
'김해중부',
'남해',
'마산동부',
'마산중부',
'밀양',
'사천',
'산청',
'양산',
'의령',
'진주',
'진해',
'창녕',
'창원서부',
'창원중부',
'통영',
'하동',
'함안',
'함양',
'함평',
'합천'
],:]
gyeongnam_20
# Out:
#         신고건수  신고성별(남자)  신고성별(여자)  신고성별(불상)  신고 성별(기타)  접수긴급유형(긴급)  접수긴급유형(중요)  \
# 경찰서명
# 거제       379       109       241        29          0          15         257
# 거창        62        19        42         1          0           2          44
# 경남청        6         1         5         0          0           1           1
# 경상남도고성    27         9        17         1          0           2          20
# 김해서부     281        66       199        16          0          18         188
# 김해중부     389       129       241        19          0          20         240
# 남해        16         7         8         1          0           2          12
# 마산동부     193        66       122         5          0           8         126
# 마산중부     166        53       110         3          0           9         114
# 밀양        85        33        44         8          0           6          50
# 사천       174        65       100         9          0           6         118
# ...

# %%
gyeongnam_20.to_csv('20_gyeongnam.csv',encoding='euc-kr')

# %%
# 2020 제주

# %%
jeju_20=df.loc[['서귀포',
'제주동부',
'제주서부',
'제주자치경찰단',
'제주청'
],:]
jeju_20
# Out:
#          신고건수  신고성별(남자)  신고성별(여자)  신고성별(불상)  신고 성별(기타)  접수긴급유형(긴급)  \
# 경찰서명
# 서귀포       218        72       142         4          0           5
# 제주동부      358       116       235         7          0           6
# 제주서부      444       125       305        14          0          12
# 제주자치경찰단     8         6         2         0          0           0
# 제주청         6         1         5         0          0           0
#
#          접수긴급유형(중요)  접수긴급유형(일반)  접수긴급유형(민원)  접수긴급유형(기타)  ...  발생시간대(14)  \
# 경찰서명                                                     ...
# 서귀포             164          37           8           4  ...          9
# 제주동부            276          57           9          10  ...         13
# 제주서부            325          68          23          16  ...         17
# 제주자치경찰단           6           0           0           2  ...          0
# 제주청               6           0           0           0  ...          1
#
# ...

# %%
jeju_20.to_csv('20_jeju.csv',encoding='euc-kr')
