# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 연도별 지역별 아동학대건수
data = pd.read_csv('child1.csv',encoding='euc-kr')
data
# Out:
#       연도  지역  아동학대건수
# 0   2016  서울    1343
# 1   2016  인천     553
# 2   2016  대전     251
# 3   2016  대구     220
# 4   2016  울산     340
# 5   2016  부산     349
# 6   2016  광주     229
# 7   2017  서울    1647
# 8   2017  인천     695
# 9   2017  대전     345
# 10  2017  대구     320
# 11  2017  울산     441
# 12  2017  부산     404
# 13  2017  광주     238
# 14  2018  서울    1354
# 15  2018  인천     875
# 16  2018  대전     420
# 17  2018  대구     379
# 18  2018  울산     398
# 19  2018  부산     616
# 20  2018  광주     263
# 21  2019  서울    1568
# 22  2019  인천    1334
# 23  2019  대전     506
# 24  2019  대구     490
# 25  2019  울산     417
# 26  2019  부산     632
# 27  2019  광주     292
# 28  2020  서울    2067
# 29  2020  인천    1373
# 30  2020  대전     554
# 31  2020  대구     567
# 32  2020  울산     440
# 33  2020  부산     585
# 34  2020  광주     363

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연도      35 non-null     int64
#  1   지역      35 non-null     object
#  2   아동학대건수  35 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 968.0+ bytes

# %%
df=pd.DataFrame(data)
df
# Out:
#       연도  지역  아동학대건수
# 0   2016  서울    1343
# 1   2016  인천     553
# 2   2016  대전     251
# 3   2016  대구     220
# 4   2016  울산     340
# 5   2016  부산     349
# 6   2016  광주     229
# 7   2017  서울    1647
# 8   2017  인천     695
# 9   2017  대전     345
# 10  2017  대구     320
# 11  2017  울산     441
# 12  2017  부산     404
# 13  2017  광주     238
# 14  2018  서울    1354
# 15  2018  인천     875
# 16  2018  대전     420
# 17  2018  대구     379
# 18  2018  울산     398
# 19  2018  부산     616
# 20  2018  광주     263
# 21  2019  서울    1568
# 22  2019  인천    1334
# 23  2019  대전     506
# 24  2019  대구     490
# 25  2019  울산     417
# 26  2019  부산     632
# 27  2019  광주     292
# 28  2020  서울    2067
# 29  2020  인천    1373
# 30  2020  대전     554
# 31  2020  대구     567
# 32  2020  울산     440
# 33  2020  부산     585
# 34  2020  광주     363

# %%
# df=df.set_index('연도')
# df

# %%
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
fm.get_fontconfig_fonts()
font_location = 'C:/Windows/Fonts/malgunbd.ttf'
font_name = fm.FontProperties(fname=font_location).get_name()
plt.rc('font', family=font_name)

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=df,x="연도",hue="지역",y="아동학대건수")
sns.set(font_scale=1.5)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.lineplot(data=df,x="연도",hue="지역",y="아동학대건수")
sns.set(font_scale=1.5)
plt.show()

# %%
# 서울, 인천, 부산

# %%
data_c = pd.read_csv('center.csv')
data_c
# Out:
#    area  시설 수  초등저학년  초등고학년    중등    고등  기타 참여 인원수
# 0    서울   414     69   3693  4284  2492        869
# 1    부산   205     46   1731  1690  1158        303
# 2    대구   200     33   2105  1897   824        142
# 3    인천   179     47   1719  1765   850        163
# 4    광주   300    100   3114  3266  1456        192
# 5    대전   146    123   1430  1487   856        211
# 6    울산    56     50    578   489   157         28
# 7    세종    11     23    125   103    29          4
# 8    경기   757    361   8057  8058  4120       1066
# 9    강원   166    196   1597  1535   817        215
# 10   충북   188    230   2188  1803   746        122
# 11   충남   232    449   2577  2172   903        250
# 12   전북   281    247   3113  2616  1094        204
# 13   전남   387    624   4186  3719  1601        180
# 14   경북   259    261   2585  2361  1094        181
# 15   경남   253    236   2674  2210  1075        218
# 16   제주    69     38    795   658   294         70

# %%
,encoding='euc-kr'

# %%
data_c=pd.DataFrame(data_c)
data_c
# Out:
#    area  시설 수  초등저학년  초등고학년    중등    고등  기타 참여 인원수
# 0    서울   414     69   3693  4284  2492        869
# 1    부산   205     46   1731  1690  1158        303
# 2    대구   200     33   2105  1897   824        142
# 3    인천   179     47   1719  1765   850        163
# 4    광주   300    100   3114  3266  1456        192
# 5    대전   146    123   1430  1487   856        211
# 6    울산    56     50    578   489   157         28
# 7    세종    11     23    125   103    29          4
# 8    경기   757    361   8057  8058  4120       1066
# 9    강원   166    196   1597  1535   817        215
# 10   충북   188    230   2188  1803   746        122
# 11   충남   232    449   2577  2172   903        250
# 12   전북   281    247   3113  2616  1094        204
# 13   전남   387    624   4186  3719  1601        180
# 14   경북   259    261   2585  2361  1094        181
# 15   경남   253    236   2674  2210  1075        218
# 16   제주    69     38    795   658   294         70

# %%
data_c['sum']=data_c['초등저학년'] + data_c['초등고학년'] +data_c['중등'] + data_c['고등']

# %%
data_c
# Out:
#    area  시설 수  초등저학년  초등고학년    중등    고등  기타 참여 인원수    sum
# 0    서울   414     69   3693  4284  2492        869  10538
# 1    부산   205     46   1731  1690  1158        303   4625
# 2    대구   200     33   2105  1897   824        142   4859
# 3    인천   179     47   1719  1765   850        163   4381
# 4    광주   300    100   3114  3266  1456        192   7936
# 5    대전   146    123   1430  1487   856        211   3896
# 6    울산    56     50    578   489   157         28   1274
# 7    세종    11     23    125   103    29          4    280
# 8    경기   757    361   8057  8058  4120       1066  20596
# 9    강원   166    196   1597  1535   817        215   4145
# 10   충북   188    230   2188  1803   746        122   4967
# 11   충남   232    449   2577  2172   903        250   6101
# 12   전북   281    247   3113  2616  1094        204   7070
# 13   전남   387    624   4186  3719  1601        180  10130
# 14   경북   259    261   2585  2361  1094        181   6301
# ...

# %%
data_c['rate']=round(data_c['sum'] / data_c['시설 수'])
data_c
# Out:
#    area  시설 수  초등저학년  초등고학년    중등    고등  기타 참여 인원수    sum  rate
# 0    서울   414     69   3693  4284  2492        869  10538  25.0
# 1    부산   205     46   1731  1690  1158        303   4625  23.0
# 2    대구   200     33   2105  1897   824        142   4859  24.0
# 3    인천   179     47   1719  1765   850        163   4381  24.0
# 4    광주   300    100   3114  3266  1456        192   7936  26.0
# 5    대전   146    123   1430  1487   856        211   3896  27.0
# 6    울산    56     50    578   489   157         28   1274  23.0
# 7    세종    11     23    125   103    29          4    280  25.0
# 8    경기   757    361   8057  8058  4120       1066  20596  27.0
# 9    강원   166    196   1597  1535   817        215   4145  25.0
# 10   충북   188    230   2188  1803   746        122   4967  26.0
# 11   충남   232    449   2577  2172   903        250   6101  26.0
# 12   전북   281    247   3113  2616  1094        204   7070  25.0
# 13   전남   387    624   4186  3719  1601        180  10130  26.0
# ...

# %%
seoul=data_c.area=='서울'
incheon=data_c.area=='인천'
busan=data_c.area=='부산'


top3=data_c.loc[seoul|incheon|busan,:]
top3
# Out:
#   area  시설 수  초등저학년  초등고학년    중등    고등  기타 참여 인원수    sum  rate
# 0   서울   414     69   3693  4284  2492        869  10538  25.0
# 1   부산   205     46   1731  1690  1158        303   4625  23.0
# 3   인천   179     47   1719  1765   850        163   4381  24.0

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
fm.get_fontconfig_fonts()
font_location = 'C:/Windows/Fonts/malgunbd.ttf'
font_name = fm.FontProperties(fname=font_location).get_name()
plt.rc('font', family=font_name)

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=top3,x="area",y="시설 수")
sns.set(font_scale=3)
plt.show()

# %%
plt.rcParams["figure.figsize"] = (10,10)

ax=total.plot(kind='bar', x='년도', y='가정폭력건수', color='#F07878')
ax2=total.plot(kind='line', x='년도', y='아동학대건수', secondary_y=True,color='#28288C', ax=ax)

ax.set_ylabel('가정폭력건수')
ax2.set_ylabel('아동폭력건수')
ax.get_legend().remove()

ax.set_ylabel('가정폭력건수')
ax2.set_label('아동학대건수')

plt.show()

# %%
data1 = pd.read_csv('do_child.csv',encoding='utf-8')
data1
# Out:
#       연도   지역  아동학대건수
# 0   2016  강원도     180
# 1   2016  경기도    1605
# 2   2016  경상도     507
# 3   2016  전라도     311
# 4   2016  제주도     104
# 5   2016  충청도     392
# 6   2017  강원도     229
# 7   2017  경기도    2079
# 8   2017  경상도     640
# 9   2017  전라도     338
# 10  2017  제주도     173
# 11  2017  충청도     519
# 12  2018  강원도     317
# 13  2018  경기도    2401
# 14  2018  경상도     680
# 15  2018  전라도     404
# 16  2018  제주도     227
# 17  2018  충청도     769
# 18  2019  강원도     332
# 19  2019  경기도    3122
# 20  2019  경상도     843
# 21  2019  전라도     540
# 22  2019  제주도     222
# 23  2019  충청도     906
# 24  2020  강원도     401
# 25  2020  경기도    3580
# 26  2020  경상도    1158
# 27  2020  전라도     533
# 28  2020  제주도     240
# 29  2020  충청도    1141

# %%
df1=pd.DataFrame(data1)
df1
# Out:
#       연도   지역  아동학대건수
# 0   2016  강원도     180
# 1   2016  경기도    1605
# 2   2016  경상도     507
# 3   2016  전라도     311
# 4   2016  제주도     104
# 5   2016  충청도     392
# 6   2017  강원도     229
# 7   2017  경기도    2079
# 8   2017  경상도     640
# 9   2017  전라도     338
# 10  2017  제주도     173
# 11  2017  충청도     519
# 12  2018  강원도     317
# 13  2018  경기도    2401
# 14  2018  경상도     680
# 15  2018  전라도     404
# 16  2018  제주도     227
# 17  2018  충청도     769
# 18  2019  강원도     332
# 19  2019  경기도    3122
# 20  2019  경상도     843
# 21  2019  전라도     540
# 22  2019  제주도     222
# 23  2019  충청도     906
# 24  2020  강원도     401
# 25  2020  경기도    3580
# 26  2020  경상도    1158
# 27  2020  전라도     533
# 28  2020  제주도     240
# 29  2020  충청도    1141

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연도      30 non-null     int64
#  1   지역      30 non-null     object
#  2   아동학대건수  30 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 848.0+ bytes

# %%
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
fm.get_fontconfig_fonts()
font_location = 'C:/Windows/Fonts/malgunbd.ttf'
font_name = fm.FontProperties(fname=font_location).get_name()
plt.rc('font', family=font_name)

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=df1,x='연도',hue='지역',y='아동학대건수')
sns.set(font_scale=1.5)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
fm.get_fontconfig_fonts()
font_location = 'C:/Windows/Fonts/malgunbd.ttf'
font_name = fm.FontProperties(fname=font_location).get_name()
plt.rc('font', family=font_name)

# %%
data=pd.read_csv("2020청소년플랫폼.csv")
data
# Out:
#    번호   회원_유형   회원_수
# 0   1    초등학생   6727
# 1   2     중학생  76574
# 2   3    고등학생  80043
# 3   4     대학생  27157
# 4   5    일반성인  14322
# 5   6  지도자/교사  13099
# 6   7  학교밖청소년   1244

# %%
sns.barplot(data=data,x="회원_유형",y="회원_수")
# Out:
# <AxesSubplot:xlabel='회원_유형', ylabel='회원_수'>
